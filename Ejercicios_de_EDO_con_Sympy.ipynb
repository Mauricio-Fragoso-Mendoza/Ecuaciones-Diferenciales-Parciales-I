# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauricio-Fragoso-Mendoza/Ecuaciones-Diferenciales-Parciales-I/blob/main/Ejercicios_de_EDO_con_Sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Resolver y graficar los siguientes problemas:
#
# 1) $X''+ kX=0$, $X(0)=X(1)=0$
#
# 2) $X''+ kX=0$, $X'(0)=X'(1)=0$

# %% [markdown]
# Solución: Primero se evaluará la ecuación $X''+kX=0$ con $X(0)=X'(0)=0$

# %% [markdown]
# Para $k=0$

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode11=sp.Eq(sp.Derivative(X(x),x,x),0)

sol11 = sp.dsolve(ode11,X(x))

const=sp.solve([sol11.rhs.subs(x,0)-0, sol11.rhs.diff(x,1).subs(x,0)-0])
C11, C21 = sp.symbols('C11,C21')
sol11=sol11.subs(const)

func1 = sp.lambdify(x,sol11.rhs,'numpy')
xx = np.arange(0,10,.1)
yy11 = func1(xx) * np.ones_like(xx)

plt.plot(xx,yy11,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()

# %% [markdown]
# Para $k > 0$ (Usando $k = x$)

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode12=sp.Eq(sp.Derivative(X(x),x,x)+x*X(x),0)

sol12 = sp.dsolve(ode12,X(x))

const=sp.solve([sol12.rhs.subs(x,0)-0, sol12.rhs.diff(x,1).subs(x,0)-0])
C12, C22 = sp.symbols('C12,C22')
sol12=sol12.subs(const)

func2 = sp.lambdify(x,sol12.rhs,'numpy')
xx = np.arange(0,10,.1)
yy12 = func2(xx) * np.ones_like(xx)

plt.plot(xx,yy12,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()

# %% [markdown]
# Para $k < 0$ (Usando $k = -x$)

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode13=sp.Eq(sp.Derivative(X(x),x,x)-x*X(x),0)

sol13 = sp.dsolve(ode13,X(x))

const=sp.solve([sol13.rhs.subs(x,0)-0, sol13.rhs.diff(x,1).subs(x,0)-0])
C13, C23 = sp.symbols('C13,C23')
sol13=sol13.subs(const)

func3 = sp.lambdify(x,sol13.rhs,'numpy')
xx = np.arange(0,10,.1)
yy13 = func3(xx) * np.ones_like(xx)

plt.plot(xx,yy13,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()

# %% [markdown]
# Posteriormente se evaluará la ecuación $X''+kX=0$ con $X(1)=X'(1)=0$

# %% [markdown]
# Para $k=0$

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode21=sp.Eq(sp.Derivative(X(x),x,x),0)

sol21 = sp.dsolve(ode21,X(x))

const=sp.solve([sol21.rhs.subs(x,1)-0, sol21.rhs.diff(x,1).subs(x,1)-0])
C14, C24 = sp.symbols('C14,C24')
sol21=sol21.subs(const)

func4 = sp.lambdify(x,sol21.rhs,'numpy')
xx = np.arange(0,10,.1)
yy21 = func4(xx) * np.ones_like(xx)

plt.plot(xx,yy21,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()

# %% [markdown]
# Para $k > 0$ (Usando $k = x$)

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode22=sp.Eq(sp.Derivative(X(x),x,x)+x*X(x),0)

sol22 = sp.dsolve(ode22,X(x))

const=sp.solve([sol22.rhs.subs(x,1)-0, sol22.rhs.diff(x,1).subs(x,1)-0])
C15, C25 = sp.symbols('C15,C25')
sol22=sol22.subs(const)

func5 = sp.lambdify(x,sol22.rhs,'numpy')
xx = np.arange(0,10,.1)
yy22 = func5(xx) * np.ones_like(xx)

plt.plot(xx,yy22,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()

# %% [markdown]
# Para $k < 0$ (Usando $k = -x$)

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x=sp.symbols('x')
X=sp.Function('X')
ode23=sp.Eq(sp.Derivative(X(x),x,x)-x*X(x),0)

sol23 = sp.dsolve(ode23,X(x))

const=sp.solve([sol23.rhs.subs(x,1)-0, sol23.rhs.diff(x,1).subs(x,1)-0])
C16, C26 = sp.symbols('C16,C26')
sol23=sol23.subs(const)

func6 = sp.lambdify(x,sol23.rhs,'numpy')
xx = np.arange(0,10,.1)
yy23 = func6(xx) * np.ones_like(xx)

plt.plot(xx,yy23,'r')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.show()
